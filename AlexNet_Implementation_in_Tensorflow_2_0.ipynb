# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniket1313/Computer-Vision-/blob/master/AlexNet_Implementation_in_Tensorflow_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

# %% [markdown]
# """After imports, we need to prepare our data.
#             Here, we will use only a small part of the ImageNet dataset.
#             With the following code you can download all images and store them in folders.
# """

# %%
import cv2
import urllib
import requests
import PIL.Image
import numpy as np
from bs4 import BeautifulSoup

# %%
#ship synset
page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n04194289")
soup = BeautifulSoup(page.content, 'html.parser')
#bicycle synset
bikes_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02834778")
bikes_soup = BeautifulSoup(bikes_page.content, 'html.parser')

# %%
str_soup=str(soup)
split_urls=str_soup.split('\r\n')

bikes_str_soup=str(bikes_soup)
bikes_split_urls=bikes_str_soup.split('\r\n')

# %%
# !mkdir /content/train
# !mkdir /content/train/ships
# !mkdir /content/train/bikes
# !mkdir /content/validation
# !mkdir /content/validation/ships
# !mkdir /content/validation/bikes
# Out:
# mkdir: cannot create directory ‘/content/train’: File exists
# mkdir: cannot create directory ‘/content/train/ships’: File exists
# mkdir: cannot create directory ‘/content/train/bikes’: File exists
# mkdir: cannot create directory ‘/content/validation’: File exists
# mkdir: cannot create directory ‘/content/validation/ships’: File exists
# mkdir: cannot create directory ‘/content/validation/bikes’: File exists

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

def url_to_image(url):
	resp = urllib.request.urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)

	return image

n_of_training_images=100
for progress in range(n_of_training_images):
    if not split_urls[progress] == None:
      try:
        I = url_to_image(split_urls[progress])
        if (len(I.shape))==3:
          save_path = '/content/train/ships/img'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

for progress in range(n_of_training_images):
    if not bikes_split_urls[progress] == None:
      try:
        I = url_to_image(bikes_split_urls[progress])
        if (len(I.shape))==3:
          save_path = '/content/train/bikes/img'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None


for progress in range(50):
    if not split_urls[progress] == None:
      try:
        I = url_to_image(split_urls[n_of_training_images+progress])
        if (len(I.shape))==3:
          save_path = '/content/validation/ships/img'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None


for progress in range(50):
    if not bikes_split_urls[progress] == None:
      try:
        I = url_to_image(bikes_split_urls[n_of_training_images+progress])
        if (len(I.shape))==3:
          save_path = '/content/validation/bikes/img'+str(progress)+'.jpg'
          cv2.imwrite(save_path,I)

      except:
        None

# %%
# !ls /content/train/ships
# !ls /content/train/bikes       
# !ls /content/validation/ships 
# !ls /content/validation/bikes
# Out:
# img0.jpg   img24.jpg  img35.jpg  img4.jpg   img62.jpg  img74.jpg  img93.jpg
# img11.jpg  img25.jpg  img39.jpg  img51.jpg  img63.jpg  img76.jpg  img94.jpg
# img12.jpg  img26.jpg  img3.jpg	 img52.jpg  img64.jpg  img77.jpg  img95.jpg
# img14.jpg  img28.jpg  img40.jpg  img54.jpg  img66.jpg  img78.jpg  img96.jpg
# img15.jpg  img29.jpg  img43.jpg  img55.jpg  img67.jpg  img83.jpg  img97.jpg
# img16.jpg  img31.jpg  img46.jpg  img56.jpg  img69.jpg  img86.jpg  img99.jpg
# img17.jpg  img32.jpg  img47.jpg  img59.jpg  img6.jpg   img8.jpg
# img18.jpg  img33.jpg  img48.jpg  img5.jpg   img72.jpg  img91.jpg
# img23.jpg  img34.jpg  img49.jpg  img60.jpg  img73.jpg  img92.jpg
# img10.jpg  img27.jpg  img47.jpg  img5.jpg   img71.jpg  img83.jpg  img95.jpg
# img13.jpg  img31.jpg  img48.jpg  img60.jpg  img72.jpg  img84.jpg  img98.jpg
# img14.jpg  img35.jpg  img4.jpg	 img63.jpg  img73.jpg  img85.jpg  img99.jpg
# img15.jpg  img36.jpg  img51.jpg  img64.jpg  img74.jpg  img86.jpg  img9.jpg
# img17.jpg  img37.jpg  img53.jpg  img65.jpg  img75.jpg  img87.jpg
# img19.jpg  img3.jpg   img54.jpg  img66.jpg  img76.jpg  img88.jpg
# img21.jpg  img41.jpg  img56.jpg  img67.jpg  img77.jpg  img89.jpg
# img22.jpg  img43.jpg  img58.jpg  img6.jpg   img78.jpg  img90.jpg
# img26.jpg  img45.jpg  img59.jpg  img70.jpg  img82.jpg  img93.jpg
# img11.jpg  img18.jpg  img2.jpg	 img35.jpg  img3.jpg   img44.jpg  img5.jpg
# img13.jpg  img20.jpg  img30.jpg  img36.jpg  img40.jpg  img46.jpg  img7.jpg
# img15.jpg  img22.jpg  img31.jpg  img37.jpg  img41.jpg  img47.jpg  img8.jpg
# img16.jpg  img25.jpg  img32.jpg  img38.jpg  img42.jpg  img48.jpg
# img17.jpg  img27.jpg  img33.jpg  img39.jpg  img43.jpg  img49.jpg
# img0.jpg   img19.jpg  img27.jpg  img34.jpg  img42.jpg  img49.jpg
# img10.jpg  img1.jpg   img29.jpg  img35.jpg  img44.jpg  img4.jpg
# img12.jpg  img20.jpg  img2.jpg	 img36.jpg  img45.jpg  img5.jpg
# img15.jpg  img22.jpg  img30.jpg  img38.jpg  img46.jpg  img6.jpg
# img17.jpg  img24.jpg  img32.jpg  img3.jpg   img47.jpg  img7.jpg
# img18.jpg  img26.jpg  img33.jpg  img41.jpg  img48.jpg  img8.jpg

# %% [markdown]
# """Now we can create a network. Last layer in the original 𝐴𝑙𝑒𝑥𝑁𝑒𝑡 has 1000 neurons,
#           but here we will use only one.
#           That is because we will use images for only two classes.
#           In order to build our convolutional neural network we will use the Sequential API.
# ![alt text](https://drive.google.com/uc?id=1fCi7WwGUjrTsSLqwN58v78Mrv3Kwns-B)
# """

# %%
num_classes = 2

# AlexNet model
class AlexNet(Sequential):
  def __init__(self, input_shape, num_classes):
    super().__init__()

    self.add(Conv2D(96, kernel_size=(11,11), strides= 4,
                    padding= 'valid', activation= 'relu',
                    input_shape= input_shape, kernel_initializer= 'he_normal'))
    self.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                          padding= 'valid', data_format= None))
    
    self.add(Conv2D(256, kernel_size=(5,5), strides= 1,
                    padding= 'same', activation= 'relu',
                    kernel_initializer= 'he_normal'))
    self.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                          padding= 'valid', data_format= None)) 

    self.add(Conv2D(384, kernel_size=(3,3), strides= 1,
                    padding= 'same', activation= 'relu',
                    kernel_initializer= 'he_normal'))
    
    self.add(Conv2D(384, kernel_size=(3,3), strides= 1,
                    padding= 'same', activation= 'relu',
                    kernel_initializer= 'he_normal'))
    
    self.add(Conv2D(256, kernel_size=(3,3), strides= 1,
                    padding= 'same', activation= 'relu',
                    kernel_initializer= 'he_normal'))
    
    self.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                          padding= 'valid', data_format= None))

    self.add(Flatten())
    self.add(Dense(4096, activation= 'relu'))
    self.add(Dense(4096, activation= 'relu'))
    self.add(Dense(1000, activation= 'relu'))
    self.add(Dense(num_classes, activation= 'softmax'))

    self.compile(optimizer= tf.keras.optimizers.Adam(0.001),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

model = AlexNet((227, 227, 3), num_classes)

model.summary()
# Out:
# Model: "alex_net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 55, 55, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 384)       885120
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 384)       1327488
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 256)       884992
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              37752832
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2002
# =================================================================
# Total params: 62,380,346
# Trainable params: 62,380,346
# Non-trainable params: 0
# _________________________________________________________________

# %%
# some training parameters
EPOCHS = 100
BATCH_SIZE = 32
image_height = 227
image_width = 227
train_dir = "train"
valid_dir = "validation"
model_dir = "my_model.h5"

# %% [markdown]
# """Data augmentation encompasses a wide range of techniques used to generate “new”
#           training samples from the original ones by applying random jitters and perturbations
#           (but at the same time ensuring that the class labels of the data are not changed).
# """

# %%
train_datagen = ImageDataGenerator(
                  rescale=1./255,
                  rotation_range=10,
                  width_shift_range=0.1,
                  height_shift_range=0.1,
                  shear_range=0.1,
                  zoom_range=0.1)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=1,
                                                    shuffle=True,
                                                    class_mode="categorical")

valid_datagen = ImageDataGenerator(rescale=1.0/255.0)
valid_generator = valid_datagen.flow_from_directory(valid_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=7,
                                                    shuffle=True,
                                                    class_mode="categorical"
                                                    )
train_num = train_generator.samples
valid_num = valid_generator.samples
# Out:
# Found 118 images belonging to 2 classes.
# Found 69 images belonging to 2 classes.

# %%
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
callback_list = [tensorboard_callback]

# %%
# start training
model.fit(train_generator,
                    epochs=EPOCHS,
                    steps_per_epoch=train_num // BATCH_SIZE,
                    validation_data=valid_generator,
                    validation_steps=valid_num // BATCH_SIZE,
                    callbacks=callback_list,
                    verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 572ms/step - loss: 0.6882 - accuracy: 0.5581 - val_loss: 0.6929 - val_accuracy: 0.4324
# Epoch 2/100
# 3/3 [==============================] - 1s 449ms/step - loss: 0.6967 - accuracy: 0.4651 - val_loss: 0.7011 - val_accuracy: 0.5405
# Epoch 3/100
# 3/3 [==============================] - 1s 457ms/step - loss: 0.6903 - accuracy: 0.5233 - val_loss: 0.7054 - val_accuracy: 0.3784
# Epoch 4/100
# 3/3 [==============================] - 1s 498ms/step - loss: 0.6912 - accuracy: 0.5312 - val_loss: 0.6949 - val_accuracy: 0.4865
# Epoch 5/100
# 3/3 [==============================] - 1s 492ms/step - loss: 0.6916 - accuracy: 0.5000 - val_loss: 0.6897 - val_accuracy: 0.5946
# Epoch 6/100
# 3/3 [==============================] - 1s 460ms/step - loss: 0.6870 - accuracy: 0.6163 - val_loss: 0.6652 - val_accuracy: 0.7297
# Epoch 7/100
# 3/3 [==============================] - 1s 460ms/step - loss: 0.6807 - accuracy: 0.6047 - val_loss: 0.6640 - val_accuracy: 0.6757
# Epoch 8/100
# 3/3 [==============================] - 1s 477ms/step - loss: 0.6687 - accuracy: 0.6667 - val_loss: 0.6786 - val_accuracy: 0.5405
# Epoch 9/100
# 3/3 [==============================] - 2s 521ms/step - loss: 0.6464 - accuracy: 0.6279 - val_loss: 0.6193 - val_accuracy: 0.6486
# Epoch 10/100
# 3/3 [==============================] - 1s 460ms/step - loss: 0.6717 - accuracy: 0.5814 - val_loss: 0.4676 - val_accuracy: 0.7568
# Epoch 11/100
# 3/3 [==============================] - 1s 450ms/step - loss: 0.5914 - accuracy: 0.6744 - val_loss: 0.5614 - val_accuracy: 0.8649
# Epoch 12/100
# 3/3 [==============================] - 1s 495ms/step - loss: 0.5646 - accuracy: 0.7188 - val_loss: 0.3956 - val_accuracy: 0.9459
# Epoch 13/100
# 3/3 [==============================] - 2s 542ms/step - loss: 0.6834 - accuracy: 0.6512 - val_loss: 0.7086 - val_accuracy: 0.6216
# Epoch 14/100
# 3/3 [==============================] - 1s 462ms/step - loss: 0.6493 - accuracy: 0.6628 - val_loss: 0.3930 - val_accuracy: 0.8108
# Epoch 15/100
# 3/3 [==============================] - 1s 458ms/step - loss: 0.5480 - accuracy: 0.7326 - val_loss: 0.4972 - val_accuracy: 0.8108
# Epoch 16/100
# 3/3 [==============================] - 1s 493ms/step - loss: 0.5227 - accuracy: 0.7604 - val_loss: 0.3420 - val_accuracy: 0.8378
# Epoch 17/100
# 3/3 [==============================] - 2s 507ms/step - loss: 0.5073 - accuracy: 0.7907 - val_loss: 0.2742 - val_accuracy: 0.9459
# Epoch 18/100
# 3/3 [==============================] - 1s 454ms/step - loss: 0.4148 - accuracy: 0.8256 - val_loss: 0.3898 - val_accuracy: 0.8649
# Epoch 19/100
# 3/3 [==============================] - 1s 469ms/step - loss: 0.4917 - accuracy: 0.8140 - val_loss: 0.3079 - val_accuracy: 0.8919
# Epoch 20/100
# 3/3 [==============================] - 1s 494ms/step - loss: 0.4291 - accuracy: 0.8333 - val_loss: 0.3143 - val_accuracy: 0.8919
# Epoch 21/100
# 3/3 [==============================] - 1s 491ms/step - loss: 0.3863 - accuracy: 0.8372 - val_loss: 0.3329 - val_accuracy: 0.8649
# Epoch 22/100
# 3/3 [==============================] - 1s 472ms/step - loss: 0.4026 - accuracy: 0.8140 - val_loss: 0.2370 - val_accuracy: 0.8919
# Epoch 23/100
# 3/3 [==============================] - 1s 471ms/step - loss: 0.3818 - accuracy: 0.8488 - val_loss: 0.3038 - val_accuracy: 0.8649
# Epoch 24/100
# 3/3 [==============================] - 1s 498ms/step - loss: 0.4091 - accuracy: 0.8333 - val_loss: 0.1364 - val_accuracy: 0.9730
# Epoch 25/100
# 3/3 [==============================] - 2s 507ms/step - loss: 0.3596 - accuracy: 0.8605 - val_loss: 0.3552 - val_accuracy: 0.8649
# Epoch 26/100
# 3/3 [==============================] - 1s 459ms/step - loss: 0.3264 - accuracy: 0.8605 - val_loss: 0.2880 - val_accuracy: 0.8919
# Epoch 27/100
# 3/3 [==============================] - 1s 470ms/step - loss: 0.4116 - accuracy: 0.8605 - val_loss: 0.2665 - val_accuracy: 0.9189
# Epoch 28/100
# 3/3 [==============================] - 1s 498ms/step - loss: 0.4340 - accuracy: 0.7917 - val_loss: 0.2653 - val_accuracy: 0.8649
# Epoch 29/100
# 3/3 [==============================] - 2s 512ms/step - loss: 0.5158 - accuracy: 0.7674 - val_loss: 0.3083 - val_accuracy: 0.8919
# Epoch 30/100
# 3/3 [==============================] - 1s 456ms/step - loss: 0.3240 - accuracy: 0.8721 - val_loss: 0.2511 - val_accuracy: 0.9189
# Epoch 31/100
# 3/3 [==============================] - 1s 453ms/step - loss: 0.4758 - accuracy: 0.8140 - val_loss: 0.6029 - val_accuracy: 0.8649
# Epoch 32/100
# 3/3 [==============================] - 1s 493ms/step - loss: 0.3911 - accuracy: 0.8646 - val_loss: 0.4413 - val_accuracy: 0.8108
# Epoch 33/100
# 3/3 [==============================] - 2s 507ms/step - loss: 0.3545 - accuracy: 0.8372 - val_loss: 0.2485 - val_accuracy: 0.7838
# Epoch 34/100
# 3/3 [==============================] - 1s 454ms/step - loss: 0.4144 - accuracy: 0.8023 - val_loss: 0.2727 - val_accuracy: 0.8919
# Epoch 35/100
# 3/3 [==============================] - 1s 459ms/step - loss: 0.3370 - accuracy: 0.8605 - val_loss: 0.6940 - val_accuracy: 0.9189
# Epoch 36/100
# 3/3 [==============================] - 1s 490ms/step - loss: 0.3195 - accuracy: 0.8854 - val_loss: 0.2054 - val_accuracy: 0.9189
# Epoch 37/100
# 3/3 [==============================] - 2s 514ms/step - loss: 0.3188 - accuracy: 0.8837 - val_loss: 0.1726 - val_accuracy: 0.9459
# Epoch 38/100
# 3/3 [==============================] - 1s 451ms/step - loss: 0.3296 - accuracy: 0.8605 - val_loss: 0.2235 - val_accuracy: 0.9189
# Epoch 39/100
# 3/3 [==============================] - 1s 450ms/step - loss: 0.2862 - accuracy: 0.8837 - val_loss: 0.2612 - val_accuracy: 0.9459
# Epoch 40/100
# 3/3 [==============================] - 2s 501ms/step - loss: 0.3485 - accuracy: 0.8438 - val_loss: 0.2334 - val_accuracy: 0.8649
# Epoch 41/100
# 3/3 [==============================] - 2s 505ms/step - loss: 0.3487 - accuracy: 0.8488 - val_loss: 0.2753 - val_accuracy: 0.8919
# Epoch 42/100
# 3/3 [==============================] - 1s 452ms/step - loss: 0.3052 - accuracy: 0.8837 - val_loss: 0.1423 - val_accuracy: 0.9730
# Epoch 43/100
# 3/3 [==============================] - 1s 457ms/step - loss: 0.2475 - accuracy: 0.8953 - val_loss: 0.3794 - val_accuracy: 0.7838
# Epoch 44/100
# 3/3 [==============================] - 1s 488ms/step - loss: 0.2792 - accuracy: 0.8750 - val_loss: 0.1419 - val_accuracy: 0.8919
# Epoch 45/100
# 3/3 [==============================] - 1s 481ms/step - loss: 0.3435 - accuracy: 0.8605 - val_loss: 0.3074 - val_accuracy: 0.9459
# Epoch 46/100
# 3/3 [==============================] - 1s 472ms/step - loss: 0.3440 - accuracy: 0.8721 - val_loss: 0.4053 - val_accuracy: 0.8108
# Epoch 47/100
# 3/3 [==============================] - 1s 448ms/step - loss: 0.2112 - accuracy: 0.9419 - val_loss: 0.3651 - val_accuracy: 0.8649
# Epoch 48/100
# 3/3 [==============================] - 1s 472ms/step - loss: 0.2062 - accuracy: 0.9271 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 2s 502ms/step - loss: 0.1736 - accuracy: 0.9186 - val_loss: 0.1919 - val_accuracy: 0.9459
# Epoch 50/100
# 3/3 [==============================] - 1s 452ms/step - loss: 0.1662 - accuracy: 0.9186 - val_loss: 0.4764 - val_accuracy: 0.8108
# Epoch 51/100
# 3/3 [==============================] - 1s 464ms/step - loss: 0.3995 - accuracy: 0.9070 - val_loss: 0.1083 - val_accuracy: 0.9459
# Epoch 52/100
# 3/3 [==============================] - 1s 484ms/step - loss: 0.3053 - accuracy: 0.8646 - val_loss: 0.2387 - val_accuracy: 0.8919
# Epoch 53/100
# 3/3 [==============================] - 1s 497ms/step - loss: 0.2141 - accuracy: 0.8953 - val_loss: 0.3276 - val_accuracy: 0.8378
# Epoch 54/100
# 3/3 [==============================] - 1s 443ms/step - loss: 0.3587 - accuracy: 0.8488 - val_loss: 0.2736 - val_accuracy: 0.8919
# Epoch 55/100
# 3/3 [==============================] - 1s 463ms/step - loss: 0.2693 - accuracy: 0.8953 - val_loss: 0.3089 - val_accuracy: 0.8649
# Epoch 56/100
# 3/3 [==============================] - 1s 491ms/step - loss: 0.2838 - accuracy: 0.8646 - val_loss: 0.1481 - val_accuracy: 0.9459
# Epoch 57/100
# 3/3 [==============================] - 2s 500ms/step - loss: 0.0822 - accuracy: 0.9884 - val_loss: 0.1254 - val_accuracy: 0.9730
# Epoch 58/100
# 3/3 [==============================] - 1s 465ms/step - loss: 0.2674 - accuracy: 0.9186 - val_loss: 0.2509 - val_accuracy: 0.9459
# Epoch 59/100
# 3/3 [==============================] - 1s 463ms/step - loss: 0.2118 - accuracy: 0.8953 - val_loss: 0.8637 - val_accuracy: 0.8378
# Epoch 60/100
# 3/3 [==============================] - 1s 491ms/step - loss: 0.3098 - accuracy: 0.8854 - val_loss: 0.1422 - val_accuracy: 0.8919
# Epoch 61/100
# 3/3 [==============================] - 2s 512ms/step - loss: 0.2039 - accuracy: 0.9186 - val_loss: 0.1443 - val_accuracy: 0.9459
# Epoch 62/100
# 3/3 [==============================] - 1s 455ms/step - loss: 0.2578 - accuracy: 0.8721 - val_loss: 0.5474 - val_accuracy: 0.8649
# Epoch 63/100
# 3/3 [==============================] - 1s 464ms/step - loss: 0.1977 - accuracy: 0.9186 - val_loss: 0.5905 - val_accuracy: 0.7568
# Epoch 64/100
# 3/3 [==============================] - 1s 485ms/step - loss: 0.1706 - accuracy: 0.9375 - val_loss: 0.5248 - val_accuracy: 0.8378
# Epoch 65/100
# 3/3 [==============================] - 2s 506ms/step - loss: 0.3017 - accuracy: 0.8721 - val_loss: 0.3082 - val_accuracy: 0.8649
# Epoch 66/100
# 3/3 [==============================] - 1s 430ms/step - loss: 0.1889 - accuracy: 0.8953 - val_loss: 0.7717 - val_accuracy: 0.7838
# Epoch 67/100
# 3/3 [==============================] - 1s 477ms/step - loss: 0.3012 - accuracy: 0.9302 - val_loss: 0.4331 - val_accuracy: 0.8378
# Epoch 68/100
# 3/3 [==============================] - 1s 488ms/step - loss: 0.2246 - accuracy: 0.9062 - val_loss: 0.1113 - val_accuracy: 0.8919
# Epoch 69/100
# 3/3 [==============================] - 2s 512ms/step - loss: 0.5840 - accuracy: 0.8372 - val_loss: 0.2186 - val_accuracy: 0.8649
# Epoch 70/100
# 3/3 [==============================] - 1s 451ms/step - loss: 0.3593 - accuracy: 0.8256 - val_loss: 0.4446 - val_accuracy: 0.8649
# Epoch 71/100
# 3/3 [==============================] - 1s 454ms/step - loss: 0.2969 - accuracy: 0.9070 - val_loss: 0.2000 - val_accuracy: 0.9189
# Epoch 72/100
# 3/3 [==============================] - 1s 484ms/step - loss: 0.2180 - accuracy: 0.9062 - val_loss: 0.3234 - val_accuracy: 0.8649
# Epoch 73/100
# 3/3 [==============================] - 1s 497ms/step - loss: 0.1993 - accuracy: 0.9535 - val_loss: 0.1026 - val_accuracy: 0.9459
# Epoch 74/100
# 3/3 [==============================] - 1s 462ms/step - loss: 0.4504 - accuracy: 0.8837 - val_loss: 0.6574 - val_accuracy: 0.7027
# Epoch 75/100
# 3/3 [==============================] - 1s 444ms/step - loss: 0.2501 - accuracy: 0.9070 - val_loss: 0.2655 - val_accuracy: 0.8378
# Epoch 76/100
# 3/3 [==============================] - 1s 475ms/step - loss: 0.1896 - accuracy: 0.9375 - val_loss: 0.4007 - val_accuracy: 0.8649
# Epoch 77/100
# 3/3 [==============================] - 2s 511ms/step - loss: 0.2731 - accuracy: 0.8488 - val_loss: 0.3124 - val_accuracy: 0.8378
# Epoch 78/100
# 3/3 [==============================] - 1s 451ms/step - loss: 0.1176 - accuracy: 0.9767 - val_loss: 0.2911 - val_accuracy: 0.8108
# Epoch 79/100
# 3/3 [==============================] - 1s 452ms/step - loss: 0.2014 - accuracy: 0.9419 - val_loss: 0.2276 - val_accuracy: 0.8919
# Epoch 80/100
# 3/3 [==============================] - 1s 493ms/step - loss: 0.1451 - accuracy: 0.9479 - val_loss: 0.4464 - val_accuracy: 0.8378
# Epoch 81/100
# 3/3 [==============================] - 1s 496ms/step - loss: 0.2023 - accuracy: 0.9419 - val_loss: 0.2968 - val_accuracy: 0.8378
# Epoch 82/100
# 3/3 [==============================] - 1s 449ms/step - loss: 0.1620 - accuracy: 0.9302 - val_loss: 0.3464 - val_accuracy: 0.8919
# Epoch 83/100
# 3/3 [==============================] - 1s 456ms/step - loss: 0.2173 - accuracy: 0.9419 - val_loss: 0.6531 - val_accuracy: 0.7838
# Epoch 84/100
# 3/3 [==============================] - 1s 484ms/step - loss: 0.1289 - accuracy: 0.9479 - val_loss: 0.5382 - val_accuracy: 0.7838
# Epoch 85/100
# 3/3 [==============================] - 1s 490ms/step - loss: 0.1288 - accuracy: 0.9651 - val_loss: 0.1505 - val_accuracy: 0.9189
# Epoch 86/100
# 3/3 [==============================] - 1s 463ms/step - loss: 0.0645 - accuracy: 0.9651 - val_loss: 0.0800 - val_accuracy: 0.9189
# Epoch 87/100
# 3/3 [==============================] - 1s 453ms/step - loss: 0.1520 - accuracy: 0.8953 - val_loss: 0.2118 - val_accuracy: 0.8378
# Epoch 88/100
# 3/3 [==============================] - 1s 483ms/step - loss: 0.0825 - accuracy: 0.9688 - val_loss: 0.2169 - val_accuracy: 0.9459
# Epoch 89/100
# 3/3 [==============================] - 2s 509ms/step - loss: 0.1955 - accuracy: 0.9651 - val_loss: 0.2401 - val_accuracy: 0.7838
# Epoch 90/100
# 3/3 [==============================] - 1s 461ms/step - loss: 0.0941 - accuracy: 0.9767 - val_loss: 0.2510 - val_accuracy: 0.8378
# Epoch 91/100
# 3/3 [==============================] - 1s 429ms/step - loss: 0.1142 - accuracy: 0.9651 - val_loss: 0.1525 - val_accuracy: 0.8378
# Epoch 92/100
# 3/3 [==============================] - 1s 496ms/step - loss: 0.0710 - accuracy: 1.0000 - val_loss: 0.3457 - val_accuracy: 0.8919
# Epoch 93/100
# 3/3 [==============================] - 2s 510ms/step - loss: 0.1815 - accuracy: 0.9302 - val_loss: 0.3276 - val_accuracy: 0.8649
# Epoch 94/100
# 3/3 [==============================] - 1s 465ms/step - loss: 0.1621 - accuracy: 0.9186 - val_loss: 0.1667 - val_accuracy: 0.9459
# Epoch 95/100
# 3/3 [==============================] - 1s 450ms/step - loss: 0.1060 - accuracy: 0.9535 - val_loss: 0.1930 - val_accuracy: 0.9189
# Epoch 96/100
# 3/3 [==============================] - 1s 477ms/step - loss: 0.1714 - accuracy: 0.9479 - val_loss: 0.0539 - val_accuracy: 0.9730
# Epoch 97/100
# 3/3 [==============================] - 2s 521ms/step - loss: 0.0795 - accuracy: 0.9884 - val_loss: 0.1892 - val_accuracy: 0.8649
# Epoch 98/100
# 3/3 [==============================] - 1s 456ms/step - loss: 0.1283 - accuracy: 0.9651 - val_loss: 0.1920 - val_accuracy: 0.9189
# Epoch 99/100
# 3/3 [==============================] - 1s 448ms/step - loss: 0.1026 - accuracy: 0.9419 - val_loss: 0.3754 - val_accuracy: 0.8649
# Epoch 100/100
# 3/3 [==============================] - 1s 485ms/step - loss: 0.1102 - accuracy: 0.9583 - val_loss: 0.1620 - val_accuracy: 0.9189

# %%
# save the whole model
model.save(model_dir)

# %%
# !kill 701

# %%
# %tensorboard --logdir logs/fit

# %%
class_names = ['bike', 'ship']
x_valid, label_batch  = next(iter(valid_generator))

prediction_values = model.predict_classes(x_valid)

# set up the figure
fig = plt.figure(figsize=(10, 6))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# plot the images: each image is 227x227 pixels
for i in range(8):
  ax = fig.add_subplot(2, 4, i + 1, xticks=[], yticks=[])
  ax.imshow(x_valid[i,:],cmap=plt.cm.gray_r, interpolation='nearest')
  
  if prediction_values[i] == np.argmax(label_batch[i]):
    # label the image with the blue text
    ax.text(3, 17, class_names[prediction_values[i]], color='blue', fontsize=14)
  else:
    # label the image with the red text
    ax.text(3, 17, class_names[prediction_values[i]], color='red', fontsize=14)
;
# Out:
# WARNING:tensorflow:From <ipython-input-21-46112f2ebf80>:4: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-46112f2ebf80> in <module>()
#      11 for i in range(8):
#      12   ax = fig.add_subplot(2, 4, i + 1, xticks=[], yticks=[])
# ---> 13   ax.imshow(x_valid[i,:],cmap=plt.cm.gray_r, interpolation='nearest')
#      14
#      15   if prediction_values[i] == np.argmax(label_batch[i]):
#
# IndexError: index 5 is out of bounds for axis 0 with size 5
